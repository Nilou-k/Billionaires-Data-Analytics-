# %%
import pandas as pd

# Load the dataset into a pandas DataFrame and read that
df = pd.read_csv('billionaires.csv')

# %%
# To display the first 5 rows of the DataFrame
df. head()
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...  location.gdp location.region          wealth.type  \
# ...

# %%
# generate a descriptive statistics summary
data_description = df.describe()

# print the summary
print(data_description)
# Out:
#               rank         year  company.founded  demographics.age  \
# count  2614.000000  2614.000000      2614.000000       2614.000000
# mean    599.672533  2008.411630      1924.711936         53.341239
# std     467.885695     7.483598       243.776546         25.333320
# min       1.000000  1996.000000         0.000000        -42.000000
# 25%     215.000000  2001.000000      1936.000000         47.000000
# 50%     430.000000  2014.000000      1963.000000         59.000000
# 75%     988.000000  2014.000000      1985.000000         70.000000
# max    1565.000000  2014.000000      2012.000000         98.000000
#
#        location.gdp  wealth.worth in billions
# count  2.614000e+03               2614.000000
# mean   1.769103e+12                  3.531943
# std    3.547083e+12                  5.088813
# min    0.000000e+00                  1.000000
# 25%    0.000000e+00                  1.400000
# 50%    0.000000e+00                  2.000000
# ...

# %%
print(df.head())
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...  location.gdp location.region          wealth.type  \
# ...

# %%
# To display the column labels of DataFrame.
print(df.columns)
# Out:
# Index(['name', 'rank', 'year', 'company.founded', 'company.name',
#        'company.relationship', 'company.sector', 'company.type',
#        'demographics.age', 'demographics.gender', 'location.citizenship',
#        'location.country code', 'location.gdp', 'location.region',
#        'wealth.type', 'wealth.worth in billions', 'wealth.how.category',
#        'wealth.how.from emerging', 'wealth.how.industry',
#        'wealth.how.inherited', 'wealth.how.was founder',
#        'wealth.how.was political'],
#       dtype='object')

# %%
# Number of rows and columns
print(df.shape)
# Out:
# (2614, 22)

# %%
# Check for missing values
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2614 entries, 0 to 2613
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      2614 non-null   object
#  1   rank                      2614 non-null   int64
#  2   year                      2614 non-null   int64
#  3   company.founded           2614 non-null   int64
#  4   company.name              2576 non-null   object
#  5   company.relationship      2568 non-null   object
#  6   company.sector            2591 non-null   object
#  7   company.type              2578 non-null   object
#  8   demographics.age          2614 non-null   int64
#  9   demographics.gender       2580 non-null   object
#  10  location.citizenship      2614 non-null   object
#  11  location.country code     2614 non-null   object
#  12  location.gdp              2614 non-null   float64
# ...

# %%
# Count the number of missing values in each column
print(df.isnull().sum())
# Out:
# name                         0
# rank                         0
# year                         0
# company.founded              0
# company.name                38
# company.relationship        46
# company.sector              23
# company.type                36
# demographics.age             0
# demographics.gender         34
# location.citizenship         0
# location.country code        0
# location.gdp                 0
# location.region              0
# wealth.type                 22
# wealth.worth in billions     0
# wealth.how.category          1
# wealth.how.from emerging     0
# wealth.how.industry          1
# wealth.how.inherited         0
# wealth.how.was founder       0
# wealth.how.was political     0
# dtype: int64

# %%
# fill in missing values with "Unknown"
df['company.name'].fillna('Unknown', inplace=True)
df['company.relationship'].fillna('Unknown', inplace=True)
df['company.sector'].fillna('Unknown', inplace=True)
df['demographics.gender'].fillna('Unknown', inplace=True)
df['wealth.type'].fillna('Unknown', inplace=True)
df['wealth.how.category'].fillna('Unknown', inplace=True)
df['wealth.how.industry'].fillna('Unknown', inplace=True)

# %%
# find duplicated rows
duplicated_data = df[df.duplicated()]

# print the duplicated rows
print(duplicated_data)
# Out:
# Empty DataFrame
# Columns: [name, rank, year, company.founded, company.name, company.relationship, company.sector, company.type, demographics.age, demographics.gender, location.citizenship, location.country code, location.gdp, location.region, wealth.type, wealth.worth in billions, wealth.how.category, wealth.how.from emerging, wealth.how.industry, wealth.how.inherited, wealth.how.was founder, wealth.how.was political]
# Index: []
#
# [0 rows x 22 columns]

# %%
# generate a descriptive statistics summary
data_description = df.describe().T

# print the summary
print(data_description)
# Out:
#                            count          mean           std     min     25%  \
# rank                      2614.0  5.996725e+02  4.678857e+02     1.0   215.0
# year                      2614.0  2.008412e+03  7.483598e+00  1996.0  2001.0
# company.founded           2614.0  1.924712e+03  2.437765e+02     0.0  1936.0
# demographics.age          2614.0  5.334124e+01  2.533332e+01   -42.0    47.0
# location.gdp              2614.0  1.769103e+12  3.547083e+12     0.0     0.0
# wealth.worth in billions  2614.0  3.531943e+00  5.088813e+00     1.0     1.4
#
#                              50%           75%           max
# rank                       430.0  9.880000e+02  1.565000e+03
# year                      2014.0  2.014000e+03  2.014000e+03
# company.founded           1963.0  1.985000e+03  2.012000e+03
# demographics.age            59.0  7.000000e+01  9.800000e+01
# location.gdp                 0.0  7.250000e+11  1.060000e+13
# wealth.worth in billions     2.0  3.500000e+00  7.600000e+01

# %%
import matplotlib.pyplot as plt

# Create histograms of the numerical columns in the DataFrame 'df'
# with a figure size of 20x20
p = df.hist(figsize=(20,20))

# Display the histograms
plt.show()

# %%
# Display the frequency of a variable
print(df['name'].value_counts())
# Out:
# Bill Gates                    3
# Gerald Cavendish Grosvenor    3
# Donald Bren                   3
# Roberto Marinho               3
# Alain Wertheimer              3
#                              ..
# Zygmunt Solorz-Zak            1
# Yvonne Bauer                  1
# Thomas Struengmann            1
# Sri Prakash Lohia             1
# Zhu Wenchen                   1
# Name: name, Length: 2077, dtype: int64

# %%
print(df['company.name'].value_counts())
# Out:
# Unknown                          38
# Walmart                          18
# Campbell Soup                    16
# Hyatt                            15
# SAP AG                           12
#                                  ..
# ESL Investment                    1
# Sun Pharmaceutical Industries     1
# Loh Group                         1
# The Stine Seed Group              1
# Furen Pharmaceutical Group        1
# Name: company.name, Length: 1578, dtype: int64

# %%
print(df['company.sector'].value_counts())
# Out:
# real estate                                177
# retail                                     120
# media                                      117
# construction                                96
# banking                                     93
#                                           ...
# food and energy processess                   1
# retail, financial services, real estate      1
# networking equipment                         1
# consumer retail                              1
# food sweeteners                              1
# Name: company.sector, Length: 521, dtype: int64

# %%
print(df['demographics.gender'].value_counts())
# Out:
# male              2328
# female             249
# Unknown             34
# married couple       3
# Name: demographics.gender, dtype: int64

# %%
print(df['location.citizenship'].value_counts())
# Out:
# United States    903
# Germany          160
# China            153
# Russia           119
# Japan             96
#                 ...
# Bahrain            1
# Ecuador            1
# Georgia            1
# Bermuda            1
# Tanzania           1
# Name: location.citizenship, Length: 73, dtype: int64

# %%
# Create a frequency table of two variables
cross_tab = pd.crosstab(df['company.sector'], df['demographics.gender'])

# Display the frequency table
print(cross_tab)
# Out:
# demographics.gender  Unknown  female  male  married couple
# company.sector
#   Oil refining             0       1     4               0
#  Communications            0       0     3               0
#  Finance                   0       2     6               0
#  Oil refining              0       0     3               0
#  Software                  0       0     3               0
# ...                      ...     ...   ...             ...
# wireless products          0       0     1               0
# wool                       0       0     1               0
# wrestling promotion        0       0     1               0
# yogurt                     0       0     1               0
# zippers                    0       0     2               0
#
# [521 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create a dataframe with the count of billionaires by country
billionaires_by_country = df.groupby('location.citizenship')['name'].count().reset_index(name='count')

# sort the dataframe in descending order and select the top 10 countries
top_10_countries = billionaires_by_country.sort_values(by='count', ascending=False).head(10)

# create a bar chart visualization
sns.set(style="whitegrid")
plt.figure(figsize=(10,5))
ax = sns.barplot(x="location.citizenship", y="count", data=top_10_countries)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.title("Top 10 Countries with the Highest Number of Billionaires")
plt.xlabel("Country")
plt.ylabel("Number of Billionaires")
plt.show()

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table of country and number of billionaires
contingency_table = pd.crosstab(df['location.citizenship'], columns='count')

# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the p-value and test result
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis. There is a significant relationship between country and number of billionaires.")
else:
    print("Fail to reject the null hypothesis. There is no significant relationship between country and number of billionaires.")
print("p-value:", p)
# Out:
# Fail to reject the null hypothesis. There is no significant relationship between country and number of billionaires.
# p-value: 1.0

# %%
import pandas as pd


# Perform label encoding on the country column
country_labels = df['location.citizenship'].astype('category').cat.codes

# Create a new dataframe with the encoded country labels and number of billionaires
encoded_df = pd.DataFrame({'country_label': country_labels, 'number_of_billionaires': df['name']})

# Compute the correlation matrix
correlation_matrix = encoded_df.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#                country_label
# country_label            1.0
# <ipython-input-31-5ffae9f6706a>:11: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = encoded_df.corr()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Perform label encoding on the country column
country_labels = df['location.citizenship'].astype('category').cat.codes

# Create a new dataframe with the encoded country labels and number of billionaires
encoded_df = pd.DataFrame({'country_label': country_labels, 'number_of_billionaires': df['name']})

# Compute the correlation matrix
correlation_matrix = encoded_df.corr()

# Create a heatmap plot of the correlation matrix
plt.figure(figsize=(5, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.xlabel('Country')
plt.ylabel('Number of billionaires')
plt.show()
# Out:
# <ipython-input-39-157a18d4aca7>:12: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = encoded_df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns for correlation analysis
numerical_columns = ['rank', 'company.founded', 'demographics.age', 'wealth.worth in billions']

# Create a subset of the dataframe with numerical columns
numerical_df = df[numerical_columns]

# Calculate the correlation matrix
correlation_matrix = numerical_df.corr()

# Create a heatmap visualization of the correlation matrix
sns.set(font_scale=1.2)
plt.figure(figsize=(7, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title("Correlation Matrix of Numerical Variables")
plt.show()

# %%
# Group the data by company sector and calculate the sum of the wealth worth in billions
sectors_by_wealth = df.groupby('company.sector')['wealth.worth in billions'].sum()

# Sort the data in descending order based on the total wealth of each sector
sectors_by_wealth = sectors_by_wealth.sort_values(ascending=False)

# Select the top 20 sectors based on their total wealth
top_20_sectors = sectors_by_wealth.head(20)

# Print the top 20 sectors
print(top_20_sectors)
# Out:
# company.sector
# real estate           618.0
# media                 486.6
# retail                481.3
# technology            263.6
# banking               245.2
# oil                   215.2
# construction          213.6
# pharmaceuticals       213.0
# groceries             178.9
# hedge funds           178.2
# software              175.0
#  Software             153.2
#  technology           126.6
#  Finance              112.8
# mining                111.8
# candy                 111.5
# luxury goods          106.7
# cars                  102.8
# investment banking     99.9
#  Communications        88.9
# Name: wealth.worth in billions, dtype: float64

# %%
import matplotlib.pyplot as plt

# Select the top 20 most successful company sectors
top_20_sectors = df['company.sector'].value_counts().nlargest(20)

# Create a bar chart
plt.figure(figsize=(7, 3))
plt.bar(top_20_sectors.index, top_20_sectors.values)
plt.xticks(rotation=90)
plt.xlabel('Company Sector')
plt.ylabel('wealth.worth in billions')
plt.title('Top 20 Most Successful Company Sectors')
plt.show()

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table of industry/sector and success
contingency_table = pd.crosstab(df['company.sector'], df['wealth.worth in billions'])

# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the p-value and test result
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis. There is a significant relationship between industry/sector and success of billionaires.")
else:
    print("Fail to reject the null hypothesis. There is no significant relationship between industry/sector and success of billionaires.")
print("p-value:", p)
# Out:
# Fail to reject the null hypothesis. There is no significant relationship between industry/sector and success of billionaires.
# p-value: 1.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant columns
selected_columns = ['company.sector', 'wealth.worth in billions']
subset_df = df[selected_columns]

# Create a contingency table
contingency_table = pd.crosstab(subset_df['company.sector'], subset_df['wealth.worth in billions'])

# Compute the correlation matrix
correlation_matrix = contingency_table.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(5, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)

# Set plot title and axis labels
plt.title('Correlation Matrix: Industry/Sector vs Success of Billionaires')
plt.xlabel('Success of Billionaires')
plt.ylabel('Industry/Sector')

# Display the plot
plt.show()

# %%
# Filter the DataFrame to only include female billionaires
female_billionaires = df[df['demographics.gender'] == 'female']

# Group the data by the "company.sector" column
sectors = female_billionaires.groupby('company.sector')

# Calculate the number of female billionaires in each sector
female_billionaires_by_sector = sectors.size().sort_values(ascending=False)

# Display the top 10 sectors with the highest number of female billionaires
print(female_billionaires_by_sector.head(10))
# Out:
# company.sector
# retail              17
# media               13
# construction        12
# soup                10
# real estate          9
# banking              8
# electronics          5
# pharmaceuticals      5
# medical supplies     5
# beer                 5
# dtype: int64

# %%
import pandas as pd
from scipy.stats import chi2_contingency


# Create a contingency table of industry and gender
contingency_table = pd.crosstab(df['company.sector'], df['demographics.gender'])

# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the p-value and test result
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis. There is a significant relationship between industry and gender of billionaires.")
else:
    print("Fail to reject the null hypothesis. There is no significant relationship between industry and gender of billionaires.")
print("p-value:", p)
# Out:
# Fail to reject the null hypothesis. There is no significant relationship between industry and gender of billionaires.
# p-value: 0.9999999999992228

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a contingency table of industry and gender
contingency_table = pd.crosstab(df['company.sector'], df['demographics.gender'])

# Calculate the correlation matrix
correlation_matrix = contingency_table.corr()

# Create a heatmap plot
plt.figure(figsize=(5, 3))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Matrix - Industry vs Gender')
plt.xlabel('Gender')
plt.ylabel('Industry')
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by sector and gender, and count the number of billionaires in each group
billionaires_by_sector_gender = df.groupby(['company.sector', 'demographics.gender'])['name'].count()

# Extract the data for female billionaires only
female_billionaires_by_sector = billionaires_by_sector_gender[:, 'female']

# Sort the data in descending order based on the number of female billionaires
female_billionaires_by_sector = female_billionaires_by_sector.sort_values(ascending=False)

# Select the top 10 sectors with the highest number of female billionaires
top_10_female_billionaire_sectors = female_billionaires_by_sector.head(10)

# Create a horizontal bar chart
plt.barh(top_10_female_billionaire_sectors.index, top_10_female_billionaire_sectors.values)

# Add chart title and axis labels
plt.title('Top 10 Sectors with the Highest Number of Female Billionaires')
plt.xlabel('Number of Female Billionaires')
plt.ylabel('Sector')

# Display the chart
plt.show()

# %%
import pandas as pd

# Read in the data
df = pd.read_csv('billionaires.csv')

# Create a new column called "age_range" that categorizes billionaires by age
bins = [0, 30, 40, 50, 60, 70, 80, 90, 100]
labels = ['Under 30', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90+']
df['age_range'] = pd.cut(df['demographics.age'], bins=bins, labels=labels)

# Group the data by age range and count the number of billionaires in each range
age_counts = df.groupby('age_range')['name'].count()

# Find the age range with the highest number of billionaires
max_age_range = age_counts.idxmax()
max_count = age_counts[max_age_range]

# Find the age range with the lowest number of billionaires
min_age_range = age_counts.idxmin()
min_count = age_counts[min_age_range]

print(f"The age range with the highest number of billionaires is {max_age_range} with {max_count} billionaires.")
print(f"The age range with the lowest number of billionaires is {min_age_range} with {min_count} billionaires.")
# Out:
# The age range with the highest number of billionaires is 60-69 with 590 billionaires.
# The age range with the lowest number of billionaires is Under 30 with 14 billionaires.

# %%
from scipy.stats import chi2_contingency

# Create age range categories based on the 'demographics.age' column
age_ranges = pd.cut(df['demographics.age'], bins=[0, 30, 40, 50, 60, 70, 80, 90, 100], labels=['Under 30', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90+'])

# Create a contingency table of age range and number of billionaires
contingency_table = pd.crosstab(age_ranges, columns='count')

# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the p-value and test result
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis. There is a significant relationship between age range and number of billionaires.")
else:
    print("Fail to reject the null hypothesis. There is no significant relationship between age range and number of billionaires.")
print("p-value:", p)
# Out:
# Fail to reject the null hypothesis. There is no significant relationship between age range and number of billionaires.
# p-value: 1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create age range categories based on the 'demographics.age' column
age_ranges = pd.cut(df['demographics.age'], bins=[0, 30, 40, 50, 60, 70, 80, 90, 100], labels=['Under 30', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90+'])

# Create a contingency table of age range and number of billionaires
contingency_table = pd.crosstab(age_ranges, columns='count')

# Compute the correlation matrix
correlation_matrix = contingency_table.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(4, 3))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Matrix - Age Range vs Number of Billionaires')
plt.xlabel('Age Range')
plt.ylabel('Number of Billionaires')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a histogram of the ages of billionaires in the dataset
plt.hist(df['demographics.age'], bins=20)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Number of Billionaires')
plt.title('Distribution of Ages for Billionaires')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by age range and count the number of billionaires in each range
age_counts = df.groupby('age_range')['name'].count()

# Create a pie chart
fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=90)
ax.set_title('Age Ranges of Billionaires')

# Show the chart
plt.show()
